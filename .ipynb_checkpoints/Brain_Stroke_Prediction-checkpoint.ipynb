# %% [markdown]
# # Brain Stroke Prediction

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.feature_selection import SequentialFeatureSelector as SFS
from imblearn.combine import SMOTETomek
from collections import Counter
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.naive_bayes import ComplementNB
from sklearn.metrics import classification_report,confusion_matrix,f1_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedShuffleSplit as SSSplit
from imblearn.ensemble import BalancedBaggingClassifier
from scipy.integrate import simps
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import OneClassSVM

# %%
if os.path.exists('brain_stroke.csv'):
    print("Alreday Present")
else:
    # !wget https://www.dropbox.com/s/fpymf1avgdhx31i/brain_stroke.csv
# Out:
# Alreday Present

# %% [markdown]
# ## Data Visualization

# %%
df=pd.read_csv('brain_stroke.csv')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
for col in df.columns:
    print("column:  {:18s} |    unique element cnt: {}".format(col, len(np.unique(df[col]))))
# Out:
# column:  gender             |    unique element cnt: 2
# column:  age                |    unique element cnt: 104
# column:  hypertension       |    unique element cnt: 2
# column:  heart_disease      |    unique element cnt: 2
# column:  ever_married       |    unique element cnt: 2
# column:  work_type          |    unique element cnt: 4
# column:  Residence_type     |    unique element cnt: 2
# column:  avg_glucose_level  |    unique element cnt: 3895
# column:  bmi                |    unique element cnt: 342
# column:  smoking_status     |    unique element cnt: 4
# column:  stroke             |    unique element cnt: 2

# %%
col_to_encode=['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

for i in col_to_encode:
    encoder=LabelEncoder()
    df[i]=encoder.fit_transform(df[i])
    print(f"{i} encoding: {dict(zip(encoder.classes_, range(len(encoder.classes_))))}")
# Out:
# gender encoding: {'Female': 0, 'Male': 1}
# ever_married encoding: {'No': 0, 'Yes': 1}
# work_type encoding: {'Govt_job': 0, 'Private': 1, 'Self-employed': 2, 'children': 3}
# Residence_type encoding: {'Rural': 0, 'Urban': 1}
# smoking_status encoding: {'Unknown': 0, 'formerly smoked': 1, 'never smoked': 2, 'smokes': 3}

# %%
df.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  4981.000000  4981.000000   4981.000000    4981.000000   4981.000000
# mean      0.416382    43.419859      0.096165       0.055210      0.658502
# std       0.493008    22.662755      0.294848       0.228412      0.474260
# min       0.000000     0.080000      0.000000       0.000000      0.000000
# 25%       0.000000    25.000000      0.000000       0.000000      0.000000
# 50%       0.000000    45.000000      0.000000       0.000000      1.000000
# 75%       1.000000    61.000000      0.000000       0.000000      1.000000
# max       1.000000    82.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  4981.000000     4981.000000        4981.000000  4981.000000
# mean      1.302349        0.508332         105.943562    28.498173
# std       0.860170        0.499981          45.075373     6.790464
# min       0.000000        0.000000          55.120000    14.000000
# 25%       1.000000        0.000000          77.230000    23.700000
# 50%       1.000000        1.000000          91.850000    28.100000
# 75%       2.000000        1.000000         113.860000    32.600000
# max       3.000000        1.000000         271.740000    48.900000
#
#        smoking_status       stroke
# count     4981.000000  4981.000000
# mean         1.379442     0.049789
# std          1.072180     0.217531
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          2.000000     0.000000
# 75%          2.000000     0.000000
# max          3.000000     1.000000

# %%
height = [len(df[df["stroke"] == 1]), len(df[df["stroke"] == 0])]
plt.figure(figsize=(4, 5))
plt.bar(["Stroke","Not Stroke"],height,width = 0.25)
plt.text(0, height[0], str(height[0]), ha="center", va="bottom")
plt.text(1, height[1], str(height[1]), ha="center", va="bottom")
plt.xlabel("Possiblity of stroke")
plt.ylabel("Number of People")
plt.title("Imbalanced data")
plt.show()

# %%
fig = plt.figure(figsize=(20, 25))
cnt = 0
temp = df
for i in df.columns[:-1]:
    if i in ["age", "avg_glucose_level", "bmi"]:
        cnt += 1
        ax = fig.add_subplot(5, 2, cnt)
        plt.xlabel(i)
        plt.ylabel("Number of People")
        bin_counts_1 = pd.cut(temp[i][temp["heart_disease"] == 1], bins=5).value_counts().sort_index()
        bin_counts_0 = pd.cut(temp[i][temp["heart_disease"] == 0], bins=5).value_counts().sort_index()
        bar_width = 0.35
        x_labels = bin_counts_1.index.values.astype(str)
        x = np.arange(len(x_labels))
        ax.bar(x - bar_width/2, bin_counts_0.values, width=bar_width, label="0",alpha = 1.0)
        ax.bar(x + bar_width/2, bin_counts_1.values, width=bar_width, label="1", color='darkorange',alpha = 1.0)
        ax.set_xticks(x)
        ax.set_xticklabels(x_labels, rotation=5)
        for j, v2, v1 in zip(x, bin_counts_1.values, bin_counts_0.values):
            ax.annotate(str(v1), xy=(j - bar_width/2, v1), ha='center', va='bottom', color='black')
            ax.annotate(str(v2), xy=(j + bar_width/2, v2), ha='center', va='bottom', color='black')
        plt.legend(title = "heart_disease")
    else:
        cnt += 1
        ax = fig.add_subplot(5, 2, cnt)
        sns.countplot(data=temp, x=i, hue="heart_disease", ax=ax)
        plt.xlabel(i)
        plt.ylabel("Number of People")
        for p in ax.patches:
            ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha = 'center', va = 'center', xytext = (0, 5), textcoords = 'offset points')

plt.show()

# %%
#Scalling the dataset
scaler = MinMaxScaler()
for col in df.columns:
    if(col!='stroke'):
        df[col] = scaler.fit_transform(np.array(df[col]).reshape(len(df[col]),1))

# %%
corr_matrix=df.corr()
plt.figure(figsize=(10, 8)) 
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
plt.title('Correlation Matrix Heatmap', fontsize=16)

# Show plot
plt.show()

# %%
X=df.drop(['heart_disease','Residence_type'],axis=1).to_numpy()
y=df['heart_disease'].to_numpy()

# %% [markdown]
# ## Splitting dat into test train and validation sets

# %%
X_train,X_temp,y_train,y_temp=tts(X,y,test_size=0.3,stratify=y)
X_val,X_test,y_val,y_test = tts(X_temp,y_temp,test_size=2/3,stratify=y_temp)
print(X_train.shape,X_val.shape)
X_train_not_sampled,y_train_not_sampled=X_train,y_train
# Out:
# (3486, 9) (498, 9)

# %% [markdown]
# ## Oversampling the training data

# %%
smk = SMOTETomek(sampling_strategy='minority', random_state=42)
X_train, y_train = smk.fit_resample(X_train, y_train)
print(X_train)
print("After Oversampling:")
print("Risk", Counter(y_train))
# Out:
# [[0.         0.49951172 0.         ... 0.66475645 0.33333333 0.        ]
#  [0.         0.42626953 0.         ... 0.45272206 1.         0.        ]
#  [0.         0.40185547 0.         ... 0.38108883 0.66666667 0.        ]
#  ...
#  [0.         0.73318444 1.         ... 0.64064025 0.61917687 0.        ]
#  [0.         0.94404051 1.         ... 0.75017411 0.63421104 0.        ]
#  [0.         0.90815996 0.         ... 0.40128101 0.33333333 0.        ]]
# After Oversampling:
# Risk Counter({0.0: 3270, 1.0: 3270})

# %%
len(X_train)
# Out:
# 6540

# %%
model_selction_dic = {}

# %% [markdown]
# ## Naive Bayes

# %%
CNB_clf=ComplementNB().fit(X_train,y_train)
y_pred=CNB_clf.predict(X_val)
print(classification_report(y_val,y_pred,target_names=['not heart_disease','heart_disease']))
model_selction_dic["Naive Bayes(Complement)"] = f1_score(y_val,y_pred)
# Out:
#                    precision    recall  f1-score   support
#
# not heart_disease       0.95      0.79      0.87       470
#     heart_disease       0.09      0.36      0.15        28
#
#          accuracy                           0.77       498
#         macro avg       0.52      0.57      0.51       498
#      weighted avg       0.91      0.77      0.82       498

# %%
print("Confusion Matrix \n\n",confusion_matrix(y_val,y_pred))
# Out:
# Confusion Matrix
#
#  [[372  98]
#  [ 18  10]]

# %% [markdown]
# ## Balanced Bagging Classifier

# %%
classifier_BBC = BalancedBaggingClassifier(estimator=DecisionTreeClassifier(),
                                sampling_strategy='not majority',
                                replacement=False,
                                random_state=42)
classifier_BBC.fit(X_train, y_train)
preds = classifier_BBC.predict(X_val)
print("f1-score for Balanced Bagging Classifier is",f1_score(y_val,preds))
model_selction_dic["Balanced Bagging Classifier"] = f1_score(y_val,preds)
print(" \n\n Classification Report \n\n",classification_report(y_val,preds,target_names=['not heart_disease','heart_disease']))
# Out:
# f1-score for Balanced Bagging Classifier is 0.20289855072463767
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.95      0.93      0.94       470
#     heart_disease       0.17      0.25      0.20        28
#
#          accuracy                           0.89       498
#         macro avg       0.56      0.59      0.57       498
#      weighted avg       0.91      0.89      0.90       498

# %%
def plot_roc_curve(clf,X,y,classes):
    y_probas=clf.predict_proba(X)
    auc_s=[]
    for idx,class_no in enumerate(classes):
        y_true=np.where(y==class_no,1,0)
        y_probs=y_probas[:,idx]
        thresholds=np.sort(y_probs)[::-1]
        tpr=[]
        fpr=[]
        for thres in thresholds:
            y_pred=np.where(y_probs>=thres,1,0)
            tn,fp,fn,tp=confusion_matrix(y_true,y_pred).ravel()
            tpr.append(tp/(tp+fn))
            fpr.append(fp/(fp+tn))
        auc=np.trapz(tpr,fpr)
        auc_s.append(auc)
        plt.plot(fpr,tpr,label=class_no,alpha=0.5,lw=5)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title("ROC Curve")
    plt.legend(bbox_to_anchor=(1.15, 1.05))
    plt.show()
    print("AUC: ",auc_s)

# %%
plot_roc_curve(classifier_BBC,X_val,y_val,[0])
# Out:
# AUC:  [0.7172492401215805]

# %%
y_prob=classifier_BBC.predict_proba(X_val)[:,1]

# %%
y_pred=[1 if y_proba>0.4 else 0 for y_proba in y_prob]

# %%
best_f1_score=-1
best_thres=-1
score_arr  = []
for thres in np.arange(0,1,0.01):
    y_pred=[1 if y_proba>thres else 0 for y_proba in y_prob]
    score=f1_score(y_val,y_pred)
    if(score>best_f1_score):
        best_f1_score=score
        best_thres=thres
    score_arr.append(score)
print(best_f1_score,best_thres)
plt.xlabel("Thresholds")
plt.ylabel("F1 - Score")
plt.plot(np.arange(0,1,0.01),score_arr)
# Out:
# 0.2330097087378641 0.3

# %% [markdown]
# ## Bagging Classifier

# %%
classifier_BC=BaggingClassifier(estimator=SVC(),n_estimators=10,random_state=42).fit(X_train,y_train)
print("f1-score for Bagging Classifier",f1_score(y_val,classifier_BC.predict(X_val)))
model_selction_dic["Bagging Classifier"] = f1_score(y_val,classifier_BC.predict(X_val))
print(" \n\n Classification Report \n\n",classification_report(y_val,classifier_BC.predict(X_val),target_names=['not heart_disease','heart_disease']))
# Out:
# f1-score for Bagging Classifier 0.267515923566879
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.98      0.77      0.86       470
#     heart_disease       0.16      0.75      0.27        28
#
#          accuracy                           0.77       498
#         macro avg       0.57      0.76      0.57       498
#      weighted avg       0.94      0.77      0.83       498

# %% [markdown]
# ## Ratio of Majority vs Miniority Class Points

# %%
len(np.where(y_train_not_sampled==0)[0])/len(np.where(y_train_not_sampled==1)[0])
# Out:
# 17.15625

# %% [markdown]
# ## Voting Ensemble

# %%
n_estimators=19
minority_indices=np.where(y_train_not_sampled==1)[0]
majority_indices=np.where(y_train_not_sampled==0)[0]
n=len(minority_indices)
np.random.shuffle(majority_indices)
start=0
end=n+1
voting_ensemble=[]
while(end<len(majority_indices)):
    train_data_indices=np.array(minority_indices)
    train_data_indices=np.append(train_data_indices,majority_indices[start:end])
    clf=DecisionTreeClassifier()
    clf.fit(X_train_not_sampled[train_data_indices],y_train_not_sampled[train_data_indices])
    voting_ensemble.append(clf)
    start+=n
    end+=n
train_data_indices=np.array(minority_indices)
train_data_indices=np.append(train_data_indices,majority_indices[start:])
clf=DecisionTreeClassifier()
clf.fit(X_train_not_sampled[train_data_indices],y_train_not_sampled[train_data_indices])
voting_ensemble.append(clf)

# %%
def pred_ensemble(voting_ensemble,X_val):
    n=len(voting_ensemble)
    predictions=voting_ensemble[0].predict(X_val)
    for i in range(1,n):
        predictions+=voting_ensemble[i].predict(X_val)
    y_pred=[1 if pred>n/2 else 0 for pred in predictions]
    print(n)
    return y_pred


def pred_proba_ensemble(voting_ensemble,X_val):
    n=len(voting_ensemble)
    proba=voting_ensemble[0].predict_proba(X_val)
    for i in range(1,n):
        proba+=voting_ensemble[i].predict_proba(X_val)   
    proba=proba/n
    return proba

# %%
y_pred=pred_ensemble(voting_ensemble,X_val)
print("Confusion Matrix \n\n",confusion_matrix(y_val,y_pred))
# Out:
# 18
# Confusion Matrix
#
#  [[334 136]
#  [  6  22]]

# %%
print("Classification Report \n\n",classification_report(y_val,y_pred))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.71      0.82       470
#          1.0       0.14      0.79      0.24        28
#
#     accuracy                           0.71       498
#    macro avg       0.56      0.75      0.53       498
# weighted avg       0.93      0.71      0.79       498

# %%
print("Accuracy for Voting Ensemble",accuracy_score(y_val,y_pred))
model_selction_dic["Voting Emsemble"] = f1_score(y_val,y_pred)
# Out:
# Accuracy for Voting Ensemble 0.714859437751004

# %% [markdown]
# ## Support Vector Classifier

# %% [markdown]
# ### SVC on undersampled data

# %%
minority_indices=np.where(y_train_not_sampled==1)[0]
majority_indices=np.where(y_train_not_sampled==0)[0]
indices=np.append(minority_indices,np.random.choice(majority_indices,len(minority_indices)))
temp_X_train=X_train_not_sampled[indices]
temp_y_train=y_train_not_sampled[indices]
clf_svc=SVC(kernel='linear',probability=True).fit(temp_X_train,temp_y_train)
print("Confusion Matrix \n\n",confusion_matrix(y_val,clf_svc.predict(X_val)))
# Out:
# Confusion Matrix
#
#  [[334 136]
#  [  3  25]]

# %%
print("f1-score for SVC is",f1_score(y_val,clf_svc.predict(X_val)))
model_selction_dic["SVC(undersampled)"] = f1_score(y_val,clf_svc.predict(X_val))
# Out:
# f1-score for SVC is 0.26455026455026454

# %%
print("Classification Report \n\n",classification_report(y_val,clf_svc.predict(X_val)))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.71      0.83       470
#          1.0       0.16      0.89      0.26        28
#
#     accuracy                           0.72       498
#    macro avg       0.57      0.80      0.55       498
# weighted avg       0.94      0.72      0.80       498

# %%
plot_roc_curve(clf_svc,X_val,y_val,[1])
# Out:
# AUC:  [0.14544072948328265]

# %% [markdown]
# ### SVC on oversampled data

# %%
clf_svc_over=SVC(kernel='linear').fit(X_train,y_train)
print(f1_score(y_val,clf_svc_over.predict(X_val)))
# Out:
# 0.27027027027027023

# %% [markdown]
# ## MLP Classifier

# %%
clf_mlp=MLPClassifier(activation='logistic', alpha=0.5, learning_rate_init=0.01, max_iter=500, solver='adam').fit(X_train,y_train)
print("Classification Report \n\n",classification_report(y_val,clf_mlp.predict(X_val)))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.77      0.86       470
#          1.0       0.16      0.75      0.26        28
#
#     accuracy                           0.77       498
#    macro avg       0.57      0.76      0.56       498
# weighted avg       0.93      0.77      0.83       498

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,clf_mlp.predict(X_val)))
model_selction_dic["MLP Classifier"] = f1_score(y_val,clf_mlp.predict(X_val))
# Out:
# Confusion Matrix
#
#  [[360 110]
#  [  7  21]]

# %% [markdown]
# ## K-Nearest Neighbour Classifier

# %%
knn_clf=KNeighborsClassifier(n_neighbors=40).fit(X_train,y_train)
print("Classification Report \n\n",classification_report(y_val,knn_clf.predict(X_val)))
model_selction_dic["K-Nearest Neighbour Classifier"] = f1_score(y_val,knn_clf.predict(X_val))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.70      0.82       470
#          1.0       0.14      0.82      0.24        28
#
#     accuracy                           0.71       498
#    macro avg       0.56      0.76      0.53       498
# weighted avg       0.94      0.71      0.79       498

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,knn_clf.predict(X_val)))
# Out:
# Confusion Matrix
#
#  [[329 141]
#  [  5  23]]

# %% [markdown]
# ### Grouping of data

# %%
sns.scatterplot(data=df,x=df.columns[7],y=df.columns[1],hue="heart_disease")
plt.title("Grouping of data")
# Out:
# Text(0.5, 1.0, 'Grouping of data')

# %% [markdown]
# ## XGB Classifier

# %%
xgb_clf=XGBClassifier(objective='binary:logistic',learning_rate=0.001).fit(X_train,y_train)
print("Confusion Matrix\n\n",confusion_matrix(y_val,xgb_clf.predict(X_val)))
# Out:
# Confusion Matrix
#
#  [[364 106]
#  [ 15  13]]

# %%
print("Classfication Report\n\n",classification_report(y_val,xgb_clf.predict(X_val)))
model_selction_dic["XGB Classifier"] = f1_score(y_val,xgb_clf.predict(X_val))
# Out:
# Classfication Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.96      0.77      0.86       470
#          1.0       0.11      0.46      0.18        28
#
#     accuracy                           0.76       498
#    macro avg       0.53      0.62      0.52       498
# weighted avg       0.91      0.76      0.82       498

# %% [markdown]
# ### Parameter tuning to find best model

# %%
best_score=0
best_model=0
for w in range(2,100):
    xgb_clf_custom=XGBClassifier(learning_rate=0.01,scale_pos_weight=w).fit(X_train,y_train)
    score=f1_score(y_val,xgb_clf_custom.predict(X_val))
    if(score>best_score):
        best_score=score
        best_model=xgb_clf_custom

# %%
print("Classification Report \n\n",classification_report(y_val,best_model.predict(X_val)))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.72      0.83       470
#          1.0       0.14      0.79      0.24        28
#
#     accuracy                           0.72       498
#    macro avg       0.56      0.75      0.54       498
# weighted avg       0.94      0.72      0.80       498

# %%
print("Best score is",best_score)
model_selction_dic["XGB Classifier"] = best_score
# Out:
# Best score is 0.24309392265193366

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,best_model.predict(X_val)))
# Out:
# Confusion Matrix
#
#  [[339 131]
#  [  6  22]]

# %% [markdown]
# ## Logistic Regression CV

# %%
classifier_LR = LogisticRegressionCV(cv=5, random_state = 0, max_iter=1000)
classifier_LR.fit(X_train, y_train.ravel())
y_pred = classifier_LR.predict(X_val)

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,classifier_LR.predict(X_val)))
# Out:
# Confusion Matrix
#
#  [[346 124]
#  [  7  21]]

# %%
print("Classification Report\n\n",classification_report(y_val,classifier_LR.predict(X_val)))
model_selction_dic["Logistic Regression"] = f1_score(y_val,classifier_LR.predict(X_val))
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.74      0.84       470
#          1.0       0.14      0.75      0.24        28
#
#     accuracy                           0.74       498
#    macro avg       0.56      0.74      0.54       498
# weighted avg       0.93      0.74      0.81       498

# %% [markdown]
# ## LDA

# %%
lda=LDA(n_components=1)
lda.fit(X_train,y_train)
X_train_lda=lda.transform(X_train)
plt.figure(figsize=(15,3))
idx=np.where(y_train==0)[0]
plt.scatter(X_train_lda[idx],np.zeros(len(idx)),c='b',s=1.25,label = "0")
idx=np.where(y_train==1)[0]
plt.scatter(X_train_lda[idx],np.zeros(len(idx)),c='r',s=1.25,label="1")
plt.title("Data points on applying LDA")
plt.legend(title = "Class")
plt.show()

# %%
y_pred=lda.predict(X_val)
print("Confusion Matrix\n\n",confusion_matrix(y_val,y_pred))
# Out:
# Confusion Matrix
#
#  [[339 131]
#  [  6  22]]

# %%
print("Classification Report\n\n",classification_report(y_val,y_pred))
model_selction_dic["LDA"] = f1_score(y_val,y_pred)
# Out:
# Classification Report
#
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.72      0.83       470
#          1.0       0.14      0.79      0.24        28
#
#     accuracy                           0.72       498
#    macro avg       0.56      0.75      0.54       498
# weighted avg       0.94      0.72      0.80       498

# %% [markdown]
# ### Logistic Regression CV

# %%
classifier_lda_LR = LogisticRegressionCV(cv=5, random_state = 0, max_iter=1000)
classifier_lda_LR.fit(X_train_lda, y_train.ravel())
y_pred = classifier_lda_LR.predict(lda.transform(X_val))

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,y_pred))
model_selction_dic["LDA(LR CV)"] = f1_score(y_val,y_pred)
print(" \n\n Classification Report \n\n",classification_report(y_val,y_pred,target_names=['not heart_disease','heart_disease']))
# Out:
# Confusion Matrix
#
#  [[339 131]
#  [  6  22]]
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.98      0.72      0.83       470
#     heart_disease       0.14      0.79      0.24        28
#
#          accuracy                           0.72       498
#         macro avg       0.56      0.75      0.54       498
#      weighted avg       0.94      0.72      0.80       498

# %% [markdown]
# ### SVC

# %%
classifier_lda_svc = SVC(kernel='linear',C=50)
classifier_lda_svc.fit(X_train_lda, y_train.ravel())
y_pred = classifier_lda_svc.predict(lda.transform(X_val))

# %%
print("Confusion Matrix\n\n",confusion_matrix(y_val,y_pred))
model_selction_dic["LDA(SVC)"] = f1_score(y_val,y_pred)
print(" \n\n Classification Report \n\n",classification_report(y_val,y_pred,target_names=['not heart_disease','heart_disease']))
# Out:
# Confusion Matrix
#
#  [[339 131]
#  [  6  22]]
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.98      0.72      0.83       470
#     heart_disease       0.14      0.79      0.24        28
#
#          accuracy                           0.72       498
#         macro avg       0.56      0.75      0.54       498
#      weighted avg       0.94      0.72      0.80       498

# %% [markdown]
# ## One Class SVM

# %%
clf_one_class_svm = OneClassSVM(nu=0.01, kernel="poly", gamma=1)
clf_one_class_svm.fit(X_train[y_train==1])
y_pred=clf_one_class_svm.predict(X_val)

# %%
y_pred[y_pred==-1]=0
print("Confusion Matrix\n\n",confusion_matrix(y_val,y_pred))
model_selction_dic["One Class SVM"] = f1_score(y_val,y_pred)
print(" \n\n Classification Report \n\n",classification_report(y_val,y_pred,target_names=['not heart_disease','heart_disease']))
# Out:
# Confusion Matrix
#
#  [[214 256]
#  [  2  26]]
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.99      0.46      0.62       470
#     heart_disease       0.09      0.93      0.17        28
#
#          accuracy                           0.48       498
#         macro avg       0.54      0.69      0.40       498
#      weighted avg       0.94      0.48      0.60       498

# %%
def platt_scale(oc_svm, X, train_size, cv_size):
	# Get SVM predictions
	y_pred = oc_svm.predict(X)
		
	# Split the data and SVM labels
	X_train, _, y_train, _ = tts(X, y_pred, train_size=train_size)

	# Train using logistic regression with cross-validation 
	lr =LogisticRegressionCV(cv=cv_size)
	lr.fit(X_train, y_train)

	return lr.predict_proba(X)


y_pred=platt_scale(clf,X_val,0.7,5)
plt.scatter(y_pred[:,0],y_pred[:,1],s=0.1)
plt.title("Probabilities of One Class SVM")
plt.xlabel("No. of points")
plt.ylabel("Probabilities")
plt.show()

# %% [markdown]
# ## Extras

# %%
temp=[]
pred=clf.predict(X_val)
for i in range(len(pred)):
    if(pred[i]==1 and y_val[i]==0):
        temp.append(y_pred[i,1])
        
temp.sort()
plt.scatter(np.arange(len(temp)),temp)

# %%
y_proba_ensemble=pred_proba_ensemble(voting_ensemble,X_val)
y_pred_ensemble=pred_ensemble(voting_ensemble,X_val)
temp=[]
for i in range(len(y_val)):
    if(y_val[i]==0 and y_pred_ensemble[i]==1):
        temp.append(y_proba_ensemble[i,1])
        
temp.sort()
plt.plot(np.arange(len(temp)),temp)
# Out:
# 18

# %%
def plot_roc_curve_ensemble(clf,X,y,classes):
    y_probas=pred_proba_ensemble(clf,X)
    best_thres=0
    best_score=0
    auc_s=[]
    for idx,class_no in enumerate(classes):
        y_true=np.where(y==class_no,1,0)
        y_probs=y_probas[:,idx]
        thresholds=np.sort(y_probs)[::-1]
        tpr=[]
        fpr=[]
        for thres in thresholds:
            y_pred=np.where(y_probs>=thres,1,0)
            tn,fp,fn,tp=confusion_matrix(y_true,y_pred).ravel()
            tpr.append(tp/(tp+fn))
            fpr.append(fp/(fp+tn))
            if(best_score<(tp/(tp+fn)-fp/(fp+tn))):
                best_score=(tp/(tp+fn)-fp/(fp+tn))
                best_thres=thres
        auc=np.trapz(tpr,fpr)
        auc_s.append(auc)
        plt.plot(fpr,tpr,label=class_no,alpha=0.5,lw=5)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(bbox_to_anchor=(1.1, 1.05))
    plt.show()
    print("AUC: ",auc_s)
    return best_thres

# %%
thres_ensemble=plot_roc_curve_ensemble(voting_ensemble,X_val,y_val,[1])
# Out:
# AUC:  [0.2040273556231003]

# %%
best_f1_score=-1
best_thres=-1
for thres in np.arange(0,1,0.01):
    temp=[1 if y_proba>thres else 0 for y_proba in y_proba_ensemble[:,1]]
    score=f1_score(y_val,temp)
    if(score>best_f1_score):
        best_f1_score=score
        best_thres=thres
        
print(best_f1_score,best_thres)
# Out:
# 0.22641509433962262 0.34

# %%
y_pred_ensemble=[1 if y_proba>(best_thres)
                 else 0 for y_proba in y_proba_ensemble[:,1]]
print(confusion_matrix(y_val,y_pred_ensemble))
print(" \n\n Classification Report \n\n",classification_report(y_val,y_pred_ensemble,target_names=['not heart_disease','heart_disease']))
# Out:
# [[310 160]
#  [  4  24]]
#
#
#  Classification Report
#
#                     precision    recall  f1-score   support
#
# not heart_disease       0.99      0.66      0.79       470
#     heart_disease       0.13      0.86      0.23        28
#
#          accuracy                           0.67       498
#         macro avg       0.56      0.76      0.51       498
#      weighted avg       0.94      0.67      0.76       498

# %%
model_selction_dic
# Out:
# {'Naive Bayes(Complement)': 0.16923076923076924,
#  'Balanced Bagging Classifier': 0.12307692307692308,
#  'Bagging Classifier': 0.21383647798742136,
#  'Voting Emsemble': 0.20689655172413793,
#  'SVC(undersampled)': 0.23913043478260868,
#  'SVC(oversampled)': 0.23333333333333334,
#  'MLP Classifier': 0.2641509433962264,
#  'K-Nearest Neighbour Classifier': 0.23958333333333337,
#  'XGB Classifier': 0.24309392265193366,
#  'Logistic Regression': 0.24277456647398843,
#  'LDA': 0.24309392265193366,
#  'LDA(LR CV)': 0.24309392265193366,
#  'LDA(SVC)': 0.24309392265193366,
#  'One Class SVM': 0.16774193548387095}
